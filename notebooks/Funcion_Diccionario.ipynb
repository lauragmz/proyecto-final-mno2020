# %% [markdown]
# ### Pasar de la base de datos a diccionario

# %%
#Cargamos el csv con los datos
import pandas as pd
df = pd.read_csv("base.csv", sep = ',',encoding='latin-1')

# %%
#Creación de función que genera el diccionario necesario para ingresar al algoritmo
def diccionario_lugares(df,fv):
    """
    Función para generar un diccinario con los lugares que visita una fuerza de venta.
    Args:
        df (dataFrame): DataFrame con la base de datos
        fv (int): Fuerza de venta del que queremos generar el diccionario.
    Returns:
        lugares(diccionario): incluye los puntos que debe visitar con sus coordenas. 
    """
    df2 = df[(df.fza_ventas == fv)]
    df2['lugar'] = range(1, len(df2) + 1)
    df2 = df2.append({'lugar' : 'base' , 'lat_destino' : df2.iloc[0]['lat_origen'],'lon_destino': df2.iloc[0]['lon_origen'] } , ignore_index=True)
    df3 = df2[['lugar','lat_destino','lon_destino']].copy()
    lugares = {a:(b,c)for a, b, c in df3.values}
    return lugares

# %%
lugares = diccionario_lugares(df,94459)
#Podemos probar con estas fuerza de venta:
# 94459- 6 lugares, Nuevo león
# 37831- 30 lugares, Jalisco
#  14738- 58 lugares, Ciudad de México
# Out:
# /home/miguelmillan13/Documentos/Programas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
lugares
# Out:
# {1: (25.671909600000003, -100.1774657),
#  2: (25.664719, -100.1628501),
#  3: (25.672287100000002, -100.1651263),
#  4: (25.678590399999997, -100.16507790000001),
#  5: (25.68714417, -100.1897223),
#  6: (25.6778829, -100.1665256),
#  'base': (25.6626, -100.204)}

# %%
import math
import random

from pycsa import CoupledAnnealer

try:
    xrange
except NameError:
    xrange = range

# %%
def distance(a, b):
    """
    Helper function to calculate the distance between two 
    latitude-longitude coordinates.
    """
    R = 6371  # radius of Earth (miles)
    lat1, lon1 = math.radians(a[0]), math.radians(a[1])
    lat2, lon2 = math.radians(b[0]), math.radians(b[1])
    return math.acos(math.sin(lat1) * math.sin(lat2) +
                     math.cos(lat1) * math.cos(lat2) * 
                     math.cos(lon1 - lon2)) * R

# Create the distance matrix between the cities.
distance_matrix = {}
for ka, va in lugares.items():
    distance_matrix[ka] = {}
    for kb, vb in lugares.items():
        if kb == ka:
            distance_matrix[ka][kb] = 0.0
        else:
            distance_matrix[ka][kb] = distance(va, vb)

# %%
def probe(positions, tgen):
    """
    Swap two cities in the route.
    
    Note that `tgen` (the generation temperature) is ignored here.
    In general, you can use `tgen` to adjust the variance of
    the probing jumps as the algorithm progress.
    """
    a = random.randint(0, len(positions) - 1)
    b = random.randint(0, len(positions) - 1)
    positions[a], positions[b] = positions[b], positions[a]
    return positions


def target(positions):
    """
    Calculates the length of the route.
    """
    e = 0
    for i in xrange(len(positions)):
        e += distance_matrix[positions[i-1]][positions[i]]
    return e

# %%
n_annealers = 10  # the number of coupled annealers

init_state = list(lugares.keys())
random.shuffle(init_state)

# Initialize the CSA process.
annealer = CoupledAnnealer(
    target, 
    probe, 
    initial_state=[init_state] * n_annealers,
    steps=200,  # You probably want to set this a lot higher, like 10,000
    processes=1,   # Only use more than 1 process if the target function is costly to compute
    n_annealers=n_annealers,
    tacc_initial=1000.0,
    verbose=1)

# Beging the annealing.
annealer.anneal()
# Out:
# Step      5, Energy 11.9253, Elapsed time 0.00 secs
# Updated acceptance temp 950.000000
# Updated generation temp 0.010000
#
# Step     10, Energy 12.3654, Elapsed time 0.00 secs
# Updated acceptance temp 902.500000
# Updated generation temp 0.010000
#
# Step     15, Energy 12.3654, Elapsed time 0.00 secs
# Updated acceptance temp 857.375000
# Updated generation temp 0.010000
#
# Step     20, Energy 12.3654, Elapsed time 0.00 secs
# Updated acceptance temp 814.506250
# Updated generation temp 0.010000
#
# Step     25, Energy 12.3654, Elapsed time 0.00 secs
# Updated acceptance temp 773.780937
# Updated generation temp 0.010000
#
# Step     30, Energy 12.6251, Elapsed time 0.00 secs
# Updated acceptance temp 735.091891
# Updated generation temp 0.009999
#
# Step     35, Energy 12.3654, Elapsed time 0.00 secs
# Updated acceptance temp 698.337296
# Updated generation temp 0.009999
#
# Step     40, Energy 12.3654, Elapsed time 0.01 secs
# Updated acceptance temp 663.420431
# Updated generation temp 0.009999
#
# Step     45, Energy 12.3654, Elapsed time 0.01 secs
# Updated acceptance temp 630.249410
# Updated generation temp 0.009999
#
# Step     50, Energy 12.3654, Elapsed time 0.01 secs
# Updated acceptance temp 598.736939
# Updated generation temp 0.009999
#
# Step     55, Energy 12.3654, Elapsed time 0.01 secs
# Updated acceptance temp 568.800092
# Updated generation temp 0.009999
#
# Step     60, Energy 12.3247, Elapsed time 0.01 secs
# Updated acceptance temp 540.360088
# Updated generation temp 0.009999
#
# Step     65, Energy 12.3247, Elapsed time 0.01 secs
# Updated acceptance temp 513.342083
# Updated generation temp 0.009999
#
# Step     70, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 487.674979
# Updated generation temp 0.009999
#
# Step     75, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 463.291230
# Updated generation temp 0.009999
#
# Step     80, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 440.126669
# Updated generation temp 0.009998
#
# Step     85, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 418.120335
# Updated generation temp 0.009998
#
# Step     90, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 397.214318
# Updated generation temp 0.009998
#
# Step     95, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 377.353603
# Updated generation temp 0.009998
#
# Step    100, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 358.485922
# Updated generation temp 0.009998
#
# Step    105, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 340.561626
# Updated generation temp 0.009998
#
# Step    110, Energy 11.9253, Elapsed time 0.01 secs
# Updated acceptance temp 323.533545
# Updated generation temp 0.009998
#
# Step    115, Energy 12.3105, Elapsed time 0.01 secs
# Updated acceptance temp 307.356868
# Updated generation temp 0.009998
#
# Step    120, Energy 12.7798, Elapsed time 0.01 secs
# Updated acceptance temp 291.989024
# Updated generation temp 0.009998
#
# Step    125, Energy 12.9466, Elapsed time 0.01 secs
# Updated acceptance temp 277.389573
# Updated generation temp 0.009998
#
# Step    130, Energy 12.9466, Elapsed time 0.02 secs
# Updated acceptance temp 263.520094
# Updated generation temp 0.009997
#
# Step    135, Energy 12.9177, Elapsed time 0.02 secs
# Updated acceptance temp 250.344090
# Updated generation temp 0.009997
#
# Step    140, Energy 12.3247, Elapsed time 0.02 secs
# Updated acceptance temp 237.826885
# Updated generation temp 0.009997
#
# Step    145, Energy 12.3247, Elapsed time 0.02 secs
# Updated acceptance temp 225.935541
# Updated generation temp 0.009997
#
# Step    150, Energy 11.8843, Elapsed time 0.02 secs
# Updated acceptance temp 214.638764
# Updated generation temp 0.009997
#
# Step    155, Energy 12.3105, Elapsed time 0.02 secs
# Updated acceptance temp 203.906826
# Updated generation temp 0.009997
#
# Step    160, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 193.711484
# Updated generation temp 0.009997
#
# Step    165, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 184.025910
# Updated generation temp 0.009997
#
# Step    170, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 174.824615
# Updated generation temp 0.009997
#
# Step    175, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 166.083384
# Updated generation temp 0.009997
#
# Step    180, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 157.779215
# Updated generation temp 0.009996
#
# Step    185, Energy 11.9253, Elapsed time 0.02 secs
# Updated acceptance temp 149.890254
# Updated generation temp 0.009996
#
# Step    190, Energy 12.7029, Elapsed time 0.02 secs
# Updated acceptance temp 142.395741
# Updated generation temp 0.009996
#
# Step    195, Energy 12.3105, Elapsed time 0.02 secs
# Updated acceptance temp 135.275954
# Updated generation temp 0.009996
#
# Step    200, Energy 12.3105, Elapsed time 0.02 secs
# Updated acceptance temp 128.512157
# Updated generation temp 0.009996

# %%
# Get the best result from all `n_annealers`.
energy, state = annealer.get_best()

# Slide the list of cities until NYC is first.
while state[0] != 'base':
    state = state[1:] + state[:1]

print()
print("%i km route:" % energy)
for city in state:
    print("\t", city)
# Out:
# 12 km route:
# 	 base
# 	 5
# 	 3
# 	 6
# 	 4
# 	 1
# 	 2
