# %%
import pandas as pd
import sys
sys.path.append('../')

# En la siguiente línea se tiene que agregar el directorio donde está instalado dynaconf y simanneal
# (esto es sólo en caso de que python no lo encuentre automáticamente)
#sys.path.append('/usr/local/lib/python3.7/site-packages')
# sys.path.append('/Users/Marco/miniconda3/envs/dpa-rita/lib/python3.8/site-packages')

from src import Utileria as ut
from src.models import particle_swarm as ps
from src.models import simulated_annealing as sa

# %% [markdown]
# # Definición del Dataframe con el que se trabajará

# %%
# Se obtiene el dataframe que contiene el grafo a evaluar:
str_Query = 'select id_origen, id_destino, distancia from trabajo.grafos where id_fza_ventas={};'

# En el query se especifica el id_fza_venta del cual se quiere obtener su grafo
df_Grafo = ut.get_data(str_Query.format(80993))
df_Grafo
# Out:
# Selecting rows from table using cursor.fetchall
# PostgreSQL connection is closed
#      id_origen  id_destino            distancia
# 0        11037  1001402004    0.267770992210818
# 1        11037  1006681965   0.3250713086280114
# 2        11037  1020053072   2.3599263518563016
# 3        11037  1020235635   1.2662382942527688
# 4        11037  1020402992  0.07674597387253217
# 5   1001402004  1006681965   0.4982193543875845
# 6   1001402004  1020053072    2.611292644038669
# 7   1001402004  1020235635   1.5321611628202725
# 8   1001402004  1020402992  0.23296305988637042
# 9   1006681965  1020053072    2.141257356651251
# 10  1006681965  1020235635   1.2140038755138276
# 11  1006681965  1020402992   0.4007658679148409
# 12  1020053072  1020235635     1.38873144493888
# 13  1020053072  1020402992   2.4237992264157247
# 14  1020235635  1020402992   1.3030556819471013

# %% [markdown]
# # ParicleSwarm

# %%
# Se crea el diccionario de hiper-parámetros que se evaluará
dict_Hiper_PS = {'Iteraciones': {10,50, 100},
              'Particulas': {2,5,100},
              'Alfa': {.4, 1},
              'Beta': {.5, 1}
              }

# %%
# %%time

# El grid search recibirá como argumentos:
# -El dataframe a evaluar
# -La clase sobre la que se realizará la búsqueda de mejores hiperparámetros
# -El diccionario de hiperparámetros
# -El número de iteraciones que se se correrán por cada combinación de hiperparámetros
df_Resultado = ut.GridSearch(df_Grafo, ps.ParticleSwarm, dict_Hiper_PS, 100)
# Out:
# CPU times: user 53.5 s, sys: 680 ms, total: 54.2 s
# Wall time: 1min 8s

# %%
# El dataframe resulado contiene las siguientes columnas:
# -Hiper-parámetros evaluados
# -Costo mínimo encontrado
# -Costo máximo encontrado
# -La moda de valor mínimo que se obtuvo por cada combinación de hp, además de su frecuencia
pd.options.display.max_colwidth = 100
df_Resultado
# Out:
#                                                       HiperParámetros  \
# 0     {'Iteraciones': 100, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 0.5}
# 1     {'Iteraciones': 100, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 1.0}
# 2     {'Iteraciones': 100, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 0.5}
# 3     {'Iteraciones': 100, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 1.0}
# 4   {'Iteraciones': 100, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 0.5}
# 5   {'Iteraciones': 100, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 1.0}
# 6   {'Iteraciones': 100, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 0.5}
# 7   {'Iteraciones': 100, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 1.0}
# 8     {'Iteraciones': 100, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 0.5}
# 9     {'Iteraciones': 100, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 1.0}
# 10    {'Iteraciones': 100, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 0.5}
# 11    {'Iteraciones': 100, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 1.0}
# 12     {'Iteraciones': 10, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 0.5}
# 13     {'Iteraciones': 10, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 1.0}
# 14     {'Iteraciones': 10, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 0.5}
# 15     {'Iteraciones': 10, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 1.0}
# 16   {'Iteraciones': 10, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 0.5}
# 17   {'Iteraciones': 10, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 1.0}
# 18   {'Iteraciones': 10, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 0.5}
# 19   {'Iteraciones': 10, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 1.0}
# 20     {'Iteraciones': 10, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 0.5}
# 21     {'Iteraciones': 10, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 1.0}
# 22     {'Iteraciones': 10, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 0.5}
# 23     {'Iteraciones': 10, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 1.0}
# 24     {'Iteraciones': 50, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 0.5}
# 25     {'Iteraciones': 50, 'Particulas': 2, 'Alfa': 0.4, 'Beta': 1.0}
# 26     {'Iteraciones': 50, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 0.5}
# 27     {'Iteraciones': 50, 'Particulas': 2, 'Alfa': 1.0, 'Beta': 1.0}
# 28   {'Iteraciones': 50, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 0.5}
# 29   {'Iteraciones': 50, 'Particulas': 100, 'Alfa': 0.4, 'Beta': 1.0}
# 30   {'Iteraciones': 50, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 0.5}
# 31   {'Iteraciones': 50, 'Particulas': 100, 'Alfa': 1.0, 'Beta': 1.0}
# 32     {'Iteraciones': 50, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 0.5}
# 33     {'Iteraciones': 50, 'Particulas': 5, 'Alfa': 0.4, 'Beta': 1.0}
# 34     {'Iteraciones': 50, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 0.5}
# 35     {'Iteraciones': 50, 'Particulas': 5, 'Alfa': 1.0, 'Beta': 1.0}
#
#    Distancia mínima (km) Distancia máxima (km) Frec. rel. dist. min.
# 0                  5.604                 8.532                 6/100
# 1                  5.604                 8.428                 6/100
# 2                  5.604                 8.145                 7/100
# 3                  5.604                 8.090                 7/100
# 4                  5.604                 5.604               100/100
# 5                  5.604                 5.659                98/100
# 6                  5.604                 5.604               100/100
# 7                  5.604                 5.659                88/100
# 8                  5.604                 6.242                32/100
# 9                  5.604                 6.203                29/100
# 10                 5.604                 7.880                47/100
# 11                 5.604                 7.546                19/100
# 12                 5.604                 8.439                 5/100
# 13                 5.604                 8.439                 5/100
# 14                 5.604                 8.442                11/100
# 15                 5.604                 8.439                 4/100
# 16                 5.604                 5.659                96/100
# 17                 5.604                 5.659                96/100
# 18                 5.604                 5.604               100/100
# 19                 5.604                 5.659                96/100
# 20                 5.604                 7.880                34/100
# 21                 5.604                 7.557                41/100
# 22                 5.604                 7.880                24/100
# 23                 5.604                 7.519                20/100
# 24                 5.604                 8.145                10/100
# 25                 5.604                 8.198                 9/100
# 26                 5.604                 8.442                 7/100
# 27                 5.604                 8.090                 4/100
# 28                 5.604                 5.659                98/100
# 29                 5.604                 5.659                98/100
# 30                 5.604                 5.659                99/100
# 31                 5.604                 5.676                88/100
# 32                 5.604                 7.519                29/100
# 33                 5.604                 6.242                32/100
# 34                 5.604                 6.240                44/100
# 35                 5.604                 7.519                19/100

# %% [markdown]
# ## Análisis de resultados de la búsqueda de mejores hiperparámetros de Particle Swarm
#
# -Insertar aquí el resultado del análisis-

# %% [markdown]
# # Simulated Annealing

# %%
# Se crea el diccionario de hiper-parámetros que se evaluará
dict_Hiper_SA = {'Tmax':{25000.0, 250.0},
              'Tmin': {2.5},
              'steps': {5000, 50},
              'updates': {10}
              }

# %%
# %%time

# El grid search recibirá como argumentos:
# -El dataframe a evaluar
# -La clase sobre la que se realizará la búsqueda de mejores hiperparámetros
# -El diccionario de hiperparámetros
# -El número de iteraciones que se se correrán por cada combinación de hiperparámetros
df_Resultado = ut.GridSearch(df_Grafo, sa.SimulatedAnnealing, dict_Hiper_SA, 5)
# Out:
#  Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.25%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.32%     0.09%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    66.70%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.08%     0.07%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.90%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.93%     0.07%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.75%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.30%     0.11%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    66.75%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.09%     0.00%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.55%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.34%     0.06%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.25%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.88%     0.07%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    69.75%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.16%     0.01%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    69.80%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    67.99%     0.00%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.70%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.05%     0.07%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.75%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.44%     0.11%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    70.15%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.46%     0.11%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.70%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.15%     0.01%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    69.60%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.12%     0.08%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    67.35%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.07%     0.00%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    67.65%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.17000          4.00    68.09%     0.00%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    67.05%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.58%     0.06%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.11000          4.00    68.30%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.11000          4.00    67.90%     0.00%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    69.85%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.20%     0.07%     0:00:06     0:00:00 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    66.75%     0.00%     0:00:01    -1:59:59 Temperature        Energy    Accept   Improve     Elapsed   Remaining
#      0.26000          4.00    68.18%     0.07%     0:00:06     0:00:00
# CPU times: user 2min 7s, sys: 1.79 s, total: 2min 9s
# Wall time: 2min 19s

# %%
# El dataframe resulado contiene las siguientes columnas:
# -Hiper-parámetros evaluados
# -Costo mínimo encontrado
# -Costo máximo encontrado
# -La moda de valor mínimo que se obtuvo por cada combinación de hp, además de su frecuencia
pd.options.display.max_colwidth = 100
df_Resultado
# Out:
#                                                 HiperParámetros  \
# 0  {'Tmax': 25000.0, 'Tmin': 2.5, 'steps': 5000, 'updates': 10}
# 1    {'Tmax': 25000.0, 'Tmin': 2.5, 'steps': 50, 'updates': 10}
# 2    {'Tmax': 250.0, 'Tmin': 2.5, 'steps': 5000, 'updates': 10}
# 3      {'Tmax': 250.0, 'Tmin': 2.5, 'steps': 50, 'updates': 10}
#
#    Distancia mínima (km)  Distancia máxima (km) Frec. rel. dist. min.
# 0                      4                      4                   5/5
# 1                      4                      4                   5/5
# 2                      4                      4                   5/5
# 3                      4                      4                   5/5

# %% [markdown]
# ## Análisis de resultados de la búsqueda de mejores hiperparámetros de Simulated Annealing
#
# -Insertar aquí el resultado del análisis-
